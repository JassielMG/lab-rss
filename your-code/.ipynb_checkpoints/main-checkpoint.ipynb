# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
# !pip install feedparser
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting feedparser
#   Downloading feedparser-6.0.8-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 895 kB/s eta 0:00:01
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Using legacy 'setup.py install' for sgmllib3k, since package 'wheel' is not installed.
# Installing collected packages: sgmllib3k, feedparser
#     Running setup.py install for sgmllib3k ... done
# Successfully installed feedparser-6.0.8 sgmllib3k-1.0.0

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
d = feedparser.parse(url)

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
d.keys()
# Out:
# dict_keys(['bozo', 'entries', 'feed', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
d.keys()
# Out:
# dict_keys(['bozo', 'entries', 'feed', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
d.entries[15].keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'published', 'published_parsed', 'authors', 'author', 'author_detail', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'content', 'wfw_commentrss', 'slash_comments', 'feedburner_origlink'])

# %%
d.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
title = d.feed.title
subtitle = d.feed.subtitle
author = d.entries[0].author
link = d.feed.link
print(f'feed: {title} \nsubtitle: {subtitle} \nauthor: {author} \nlink: {link}')
# Out:
# feed: Radar
# subtitle: Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
# author: Mike Loukides
# link: https://www.oreilly.com/radar

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(d.entries)
# Out:
# 60

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
components = list(d.entries[0].keys())
components
# Out:
# ['title',
#  'title_detail',
#  'links',
#  'link',
#  'comments',
#  'published',
#  'published_parsed',
#  'authors',
#  'author',
#  'author_detail',
#  'tags',
#  'id',
#  'guidislink',
#  'summary',
#  'summary_detail',
#  'content',
#  'wfw_commentrss',
#  'slash_comments',
#  'feedburner_origlink']

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
titles = []

for i in d.entries:
    titles.append(i.title) 
titles
# Out:
# ['Radar trends to watch: July 2021',
#  'Hand Labeling Considered Harmful',
#  'Two economies. Two sets of rules.',
#  'Communal Computing',
#  'Code as Infrastructure',
#  'Radar trends to watch: June 2021',
#  'AI Powered Misinformation and Manipulation at Scale #GPT-3',
#  'DeepCheapFakes',
#  'Radar trends to watch: May 2021',
#  'Checking Jeff Bezos’s Math',
#  'AI Adoption in the Enterprise 2021',
#  'NFTs: Owning Digital Art',
#  'Radar trends to watch: April 2021',
#  'InfoTribes, Reality Brokers',
#  'The End of Silicon Valley as We Know It?',
#  'The Next Generation of AI',
#  'Radar trends to watch: March 2021',
#  'Product Management for AI',
#  '5 things on our data and AI radar for 2021',
#  '5 infrastructure and operations trends to watch in 2021',
#  'The Wrong Question',
#  'Radar trends to watch: February 2021',
#  'Where Programming, Ops, AI, and the Cloud are Headed in 2021',
#  'Seven Legal Questions for Data Scientists',
#  'Patterns',
#  'Radar trends to watch: January 2021',
#  'Four short links: 14 Dec 2020',
#  'Four short links: 8 Dec 2020',
#  'O’Reilly’s top 20 live online training courses of 2020',
#  'What is functional programming?',
#  'Four short links: 4 Dec 2020',
#  'Four short links: 1 Dec 2020',
#  'Radar trends to watch: December 2020',
#  'Four short links: 27 Nov 2020',
#  'Four short links: 24 Nov 2020',
#  'Four short links: 20 Nov 2020',
#  'On Exactitude in Technical Debt',
#  'Four short links: 17 Nov 2020',
#  'Four short links: 13 Nov 2020',
#  'Multi-Paradigm Languages',
#  'Four short links: 10 November 2020',
#  'Four short links: 6 Nov 2020',
#  'Four short links: 4 Nov 2020',
#  'Radar trends to watch: November 2020',
#  'Four short links: 30 Oct 2020',
#  'Four short links: 28 Oct 2020',
#  'Our Favorite Questions',
#  'Four short links: 21 Oct 2020',
#  'Four Short Links: 16 October 2020',
#  'Four short links: 14 Oct 2020',
#  'AI Product Management After Deployment',
#  'Four short links: 9 October 2020',
#  'AI and Creativity',
#  'Four short links: 6 October 2020',
#  'Four short links: 2 October 2020',
#  'Radar trends to watch: October 2020',
#  'Four short links: 29 Sep 2020',
#  'Four short links: 25 September 2020',
#  'Four short links: 18 Sep 2020',
#  'Four short links: 16 Sep 2020']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
short_links = []

for i in titles:
    if i.startswith('Four short links'):
        short_links.append(i)

p = len(short_links)/len(titles)

print('Percentage: ',str(round(p*100,4)) + ' ' + '%')
# Out:
# Percentage:  38.3333 %

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df = pd.json_normalize(d.entries)
df
# Out:
#                                                 title  \
# 0                    Radar trends to watch: July 2021
# 1                    Hand Labeling Considered Harmful
# 2                   Two economies. Two sets of rules.
# 3                                  Communal Computing
# 4                              Code as Infrastructure
# 5                    Radar trends to watch: June 2021
# 6   AI Powered Misinformation and Manipulation at ...
# 7                                      DeepCheapFakes
# 8                     Radar trends to watch: May 2021
# 9                          Checking Jeff Bezos’s Math
# 10                 AI Adoption in the Enterprise 2021
# 11                           NFTs: Owning Digital Art
# 12                  Radar trends to watch: April 2021
# 13                        InfoTribes, Reality Brokers
# 14           The End of Silicon Valley as We Know It?
# 15                          The Next Generation of AI
# 16                  Radar trends to watch: March 2021
# 17                          Product Management for AI
# 18         5 things on our data and AI radar for 2021
# 19  5 infrastructure and operations trends to watc...
# 20                                 The Wrong Question
# 21               Radar trends to watch: February 2021
# 22  Where Programming, Ops, AI, and the Cloud are ...
# 23          Seven Legal Questions for Data Scientists
# 24                                           Patterns
# 25                Radar trends to watch: January 2021
# 26                      Four short links: 14 Dec 2020
# 27                       Four short links: 8 Dec 2020
# 28  O’Reilly’s top 20 live online training courses...
# 29                    What is functional programming?
# 30                       Four short links: 4 Dec 2020
# 31                       Four short links: 1 Dec 2020
# 32               Radar trends to watch: December 2020
# 33                      Four short links: 27 Nov 2020
# 34                      Four short links: 24 Nov 2020
# 35                      Four short links: 20 Nov 2020
# 36                    On Exactitude in Technical Debt
# 37                      Four short links: 17 Nov 2020
# 38                      Four short links: 13 Nov 2020
# 39                           Multi-Paradigm Languages
# 40                 Four short links: 10 November 2020
# 41                       Four short links: 6 Nov 2020
# 42                       Four short links: 4 Nov 2020
# 43               Radar trends to watch: November 2020
# 44                      Four short links: 30 Oct 2020
# 45                      Four short links: 28 Oct 2020
# 46                             Our Favorite Questions
# 47                      Four short links: 21 Oct 2020
# 48                  Four Short Links: 16 October 2020
# 49                      Four short links: 14 Oct 2020
# 50             AI Product Management After Deployment
# 51                   Four short links: 9 October 2020
# 52                                  AI and Creativity
# 53                   Four short links: 6 October 2020
# 54                   Four short links: 2 October 2020
# 55                Radar trends to watch: October 2020
# 56                      Four short links: 29 Sep 2020
# 57                Four short links: 25 September 2020
# 58                      Four short links: 18 Sep 2020
# 59                      Four short links: 16 Sep 2020
#
#                                                 links  \
# 0   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 5   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 6   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 7   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 8   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 9   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 10  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 11  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 12  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 13  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 14  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
# 51  Fri, 09 Oct 2020 11:32:21 +0000   (2020, 10, 9, 11, 32, 21, 4, 283, 0)
# 52  Tue, 06 Oct 2020 12:04:48 +0000    (2020, 10, 6, 12, 4, 48, 1, 280, 0)
# 53  Tue, 06 Oct 2020 11:25:54 +0000   (2020, 10, 6, 11, 25, 54, 1, 280, 0)
# 54  Fri, 02 Oct 2020 11:46:31 +0000   (2020, 10, 2, 11, 46, 31, 4, 276, 0)
# 55  Thu, 01 Oct 2020 11:50:46 +0000   (2020, 10, 1, 11, 50, 46, 3, 275, 0)
# 56  Tue, 29 Sep 2020 11:23:08 +0000    (2020, 9, 29, 11, 23, 8, 1, 273, 0)
# 57  Fri, 25 Sep 2020 12:25:34 +0000   (2020, 9, 25, 12, 25, 34, 4, 269, 0)
# 58  Fri, 18 Sep 2020 12:52:20 +0000   (2020, 9, 18, 12, 52, 20, 4, 262, 0)
# 59  Wed, 16 Sep 2020 10:58:34 +0000   (2020, 9, 16, 10, 58, 34, 2, 260, 0)
#
#                                               authors  \
# 0                         [{'name': 'Mike Loukides'}]
# 1   [{'name': 'Shayan Mohanty and Hugo Bowne-Ander...
# 2                          [{'name': 'Tim O’Reilly'}]
# 3                          [{'name': 'Chris Butler'}]
# 4                         [{'name': 'Mike Loukides'}]
# 5                         [{'name': 'Mike Loukides'}]
# 6                       [{'name': 'Nitesh Dhanjani'}]
# 7                         [{'name': 'Mike Loukides'}]
# 8                         [{'name': 'Mike Loukides'}]
# 9                          [{'name': 'Tim O’Reilly'}]
# 10                        [{'name': 'Mike Loukides'}]
# 11                        [{'name': 'Mike Loukides'}]
# 12                        [{'name': 'Mike Loukides'}]
# 13                  [{'name': 'Hugo Bowne-Anderson'}]
# 14                         [{'name': 'Tim O’Reilly'}]
# 15                        [{'name': 'Mike Loukides'}]
# 16                        [{'name': 'Mike Loukides'}]
# 17                        [{'name': 'Mike Loukides'}]
# 18                                               [{}]
# 19                                               [{}]
# 20                        [{'name': 'Mike Loukides'}]
# 21                        [{'name': 'Mike Loukides'}]
# 22                        [{'name': 'Mike Loukides'}]
# 23      [{'name': 'Patrick Hall and Ayoub Ouederni'}]
# 24                        [{'name': 'Mike Loukides'}]
# 25                        [{'name': 'Mike Loukides'}]
# 26                       [{'name': 'Nat Torkington'}]
# 27                       [{'name': 'Nat Torkington'}]
# 28                                               [{}]
# 29                        [{'name': 'Mike Loukides'}]
# 30                       [{'name': 'Nat Torkington'}]
# 31                       [{'name': 'Nat Torkington'}]
# 32                        [{'name': 'Mike Loukides'}]
# 33                       [{'name': 'Nat Torkington'}]
# 34                       [{'name': 'Nat Torkington'}]
# 35                       [{'name': 'Nat Torkington'}]
# 36                        [{'name': 'Kevlin Henney'}]
# 37                       [{'name': 'Nat Torkington'}]
# 38                       [{'name': 'Nat Torkington'}]
# 39                        [{'name': 'Mike Loukides'}]
# 40                       [{'name': 'Nat Torkington'}]
# 41                       [{'name': 'Nat Torkington'}]
# 42                       [{'name': 'Nat Torkington'}]
# 43                        [{'name': 'Mike Loukides'}]
# 44                       [{'name': 'Nat Torkington'}]
# 45                       [{'name': 'Nat Torkington'}]
# 46  [{'name': 'Q Ethan McCallum, Chris Butler and ...
# 47                       [{'name': 'Nat Torkington'}]
# 48                                               [{}]
# 49                       [{'name': 'Nat Torkington'}]
# 50      [{'name': 'Justin Norman and Mike Loukides'}]
# 51                       [{'name': 'Nat Torkington'}]
# 52                        [{'name': 'Mike Loukides'}]
# 53                       [{'name': 'Nat Torkington'}]
# 54                       [{'name': 'Nat Torkington'}]
# 55                        [{'name': 'Mike Loukides'}]
# 56                       [{'name': 'Nat Torkington'}]
# 57                       [{'name': 'Nat Torkington'}]
# 58                       [{'name': 'Nat Torkington'}]
# 59                       [{'name': 'Nat Torkington'}]
#
#                                             author  \
# 0                                    Mike Loukides
# 1           Shayan Mohanty and Hugo Bowne-Anderson
# 2                                     Tim O’Reilly
# 3                                     Chris Butler
# 4                                    Mike Loukides
# 5                                    Mike Loukides
# 6                                  Nitesh Dhanjani
# 7                                    Mike Loukides
# 8                                    Mike Loukides
# 9                                     Tim O’Reilly
# 10                                   Mike Loukides
# 11                                   Mike Loukides
# 12                                   Mike Loukides
# 13                             Hugo Bowne-Anderson
# 14                                    Tim O’Reilly
# 15                                   Mike Loukides
# 16                                   Mike Loukides
# 17                                   Mike Loukides
# 18
# 19
# 20                                   Mike Loukides
# 21                                   Mike Loukides
# 22                                   Mike Loukides
# 23                 Patrick Hall and Ayoub Ouederni
# 24                                   Mike Loukides
# 25                                   Mike Loukides
# 26                                  Nat Torkington
# 27                                  Nat Torkington
# 28
# 29                                   Mike Loukides
# 30                                  Nat Torkington
# 31                                  Nat Torkington
# 32                                   Mike Loukides
# 33                                  Nat Torkington
# 34                                  Nat Torkington
# 35                                  Nat Torkington
# 36                                   Kevlin Henney
# 37                                  Nat Torkington
# 38                                  Nat Torkington
# 39                                   Mike Loukides
# 40                                  Nat Torkington
# 41                                  Nat Torkington
# 42                                  Nat Torkington
# 43                                   Mike Loukides
# 44                                  Nat Torkington
# 45                                  Nat Torkington
# 46  Q Ethan McCallum, Chris Butler and Shane Glynn
# 47                                  Nat Torkington
# 48
# 49                                  Nat Torkington
# 50                 Justin Norman and Mike Loukides
# 51                                  Nat Torkington
# 52                                   Mike Loukides
# 53                                  Nat Torkington
# 54                                  Nat Torkington
# 55                                   Mike Loukides
# 56                                  Nat Torkington
# 57                                  Nat Torkington
# 58                                  Nat Torkington
# 59                                  Nat Torkington
#
#                                                  tags  \
# 0   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 1   [{'term': 'Artificial Intelligence', 'scheme':...
# 2   [{'term': 'Bubbles', 'scheme': None, 'label': ...
# 3   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 4   [{'term': 'Infrastructure', 'scheme': None, 'l...
# 5   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 6   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 7   [{'term': 'Artificial Intelligence', 'scheme':...
# 8   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 9   [{'term': 'Business', 'scheme': None, 'label':...
# 10  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 11  [{'term': 'Building a data culture', 'scheme':...
# 12  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 13  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 14  [{'term': 'Radar Column', 'scheme': None, 'lab...
# 15  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 16  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 17  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 18  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 19  [{'term': 'Infrastructure', 'scheme': None, 'l...
# 20  [{'term': 'Intelligence matters: Artificial in...
# 21  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 22  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 23  [{'term': 'Artificial Intelligence', 'scheme':...
# 24  [{'term': 'Radar Column', 'scheme': None, 'lab...
# 25  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 26  [{'term': 'Four Short Links', 'scheme': None, ...
# 27  [{'term': 'Four Short Links', 'scheme': None, ...
# 28  [{'term': 'O'Reilly Insights', 'scheme': None,...
# 29  [{'term': 'Radar Column', 'scheme': None, 'lab...
# 30  [{'term': 'Four Short Links', 'scheme': None, ...
# 31  [{'term': 'Four Short Links', 'scheme': None, ...
# 32  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 33  [{'term': 'Four Short Links', 'scheme': None, ...
# 34  [{'term': 'Four Short Links', 'scheme': None, ...
# 35  [{'term': 'Four Short Links', 'scheme': None, ...
# 36  [{'term': 'Commentary', 'scheme': None, 'label...
# 37  [{'term': 'Four Short Links', 'scheme': None, ...
# 38  [{'term': 'Four Short Links', 'scheme': None, ...
# 39  [{'term': 'Software Engineering', 'scheme': No...
# 40  [{'term': 'Four Short Links', 'scheme': None, ...
# 41  [{'term': 'Four Short Links', 'scheme': None, ...
# 42  [{'term': 'Four Short Links', 'scheme': None, ...
# 43  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 44  [{'term': 'Four Short Links', 'scheme': None, ...
# 45  [{'term': 'Four Short Links', 'scheme': None, ...
# 46  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 47  [{'term': 'Four Short Links', 'scheme': None, ...
# 48                                                NaN
# 49  [{'term': 'Four Short Links', 'scheme': None, ...
# 50  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 51  [{'term': 'Four Short Links', 'scheme': None, ...
# 52  [{'term': 'Commentary', 'scheme': None, 'label...
# 53  [{'term': 'Four Short Links', 'scheme': None, ...
# 54  [{'term': 'Four Short Links', 'scheme': None, ...
# 55  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 56  [{'term': 'Four Short Links', 'scheme': None, ...
# 57  [{'term': 'Four Short Links', 'scheme': None, ...
# 58  [{'term': 'Four Short Links', 'scheme': None, ...
# 59  [{'term': 'Four Short Links', 'scheme': None, ...
#
#                                         id  ...  \
# 0   https://www.oreilly.com/radar/?p=13856  ...
# 1   https://www.oreilly.com/radar/?p=13825  ...
# 2   https://www.oreilly.com/radar/?p=13820  ...
# 3   https://www.oreilly.com/radar/?p=13812  ...
# 4   https://www.oreilly.com/radar/?p=13808  ...
# 5   https://www.oreilly.com/radar/?p=13803  ...
# 6   https://www.oreilly.com/radar/?p=13789  ...
# 7   https://www.oreilly.com/radar/?p=13768  ...
# 8   https://www.oreilly.com/radar/?p=13755  ...
# 9   https://www.oreilly.com/radar/?p=13748  ...
# 10  https://www.oreilly.com/radar/?p=13720  ...
# 11  https://www.oreilly.com/radar/?p=13713  ...
# 12  https://www.oreilly.com/radar/?p=13706  ...
# 13  https://www.oreilly.com/radar/?p=13687  ...
# 14  https://www.oreilly.com/radar/?p=13665  ...
# 15  https://www.oreilly.com/radar/?p=13676  ...
# 16  https://www.oreilly.com/radar/?p=13672  ...
# 17  https://www.oreilly.com/radar/?p=13646  ...
# 18  https://www.oreilly.com/radar/?p=13660  ...
# 19  https://www.oreilly.com/radar/?p=13648  ...
# 20  https://www.oreilly.com/radar/?p=13637  ...
# 21  https://www.oreilly.com/radar/?p=13630  ...
# 22  https://www.oreilly.com/radar/?p=13616  ...
# 23  https://www.oreilly.com/radar/?p=13610  ...
# 24  https://www.oreilly.com/radar/?p=13601  ...
# 10                 AI Adoption in the Enterprise 2021
# 11                           NFTs: Owning Digital Art
# 12                  Radar trends to watch: April 2021
# 13                        InfoTribes, Reality Brokers
# 14           The End of Silicon Valley as We Know It?
# 15                          The Next Generation of AI
# 16                  Radar trends to watch: March 2021
# 17                          Product Management for AI
# 18         5 things on our data and AI radar for 2021
# 19  5 infrastructure and operations trends to watc...
# 20                                 The Wrong Question
# 21               Radar trends to watch: February 2021
# 22  Where Programming, Ops, AI, and the Cloud are ...
# 23          Seven Legal Questions for Data Scientists
# 24                                           Patterns
# 25                Radar trends to watch: January 2021
# 26                      Four short links: 14 Dec 2020
# 27                       Four short links: 8 Dec 2020
# 28  O’Reilly’s top 20 live online training courses...
# 29                    What is functional programming?
# 30                       Four short links: 4 Dec 2020
# 31                       Four short links: 1 Dec 2020
# 32               Radar trends to watch: December 2020
# 33                      Four short links: 27 Nov 2020
# 34                      Four short links: 24 Nov 2020
# 35                      Four short links: 20 Nov 2020
# 36                    On Exactitude in Technical Debt
# 37                      Four short links: 17 Nov 2020
# 38                      Four short links: 13 Nov 2020
# 39                           Multi-Paradigm Languages
# 40                 Four short links: 10 November 2020
# 41                       Four short links: 6 Nov 2020
# 42                       Four short links: 4 Nov 2020
# 43               Radar trends to watch: November 2020
# 44                      Four short links: 30 Oct 2020
# 45                      Four short links: 28 Oct 2020
# 46                             Our Favorite Questions
# 47                      Four short links: 21 Oct 2020
# 48                  Four Short Links: 16 October 2020
# 49                      Four short links: 14 Oct 2020
# 50             AI Product Management After Deployment
# 51                   Four short links: 9 October 2020
# 52                                  AI and Creativity
# 53                   Four short links: 6 October 2020
# 54                   Four short links: 2 October 2020
# 55                Radar trends to watch: October 2020
# 56                      Four short links: 29 Sep 2020
# 57                Four short links: 25 September 2020
# 58                      Four short links: 18 Sep 2020
# 59                      Four short links: 16 Sep 2020
#
#                                 author_detail.name summary_detail.type  \
# 0                                    Mike Loukides           text/html
# 1           Shayan Mohanty and Hugo Bowne-Anderson           text/html
# 2                                     Tim O’Reilly           text/html
# 3                                     Chris Butler           text/html
# 4                                    Mike Loukides           text/html
# 5                                    Mike Loukides           text/html
# 6                                  Nitesh Dhanjani           text/html
# 7                                    Mike Loukides           text/html
# 8                                    Mike Loukides           text/html
# 9                                     Tim O’Reilly           text/html
# 10                                   Mike Loukides           text/html
# 11                                   Mike Loukides           text/html
# 12                                   Mike Loukides           text/html
# 13                             Hugo Bowne-Anderson           text/html
# 14                                    Tim O’Reilly           text/html
# 15                                   Mike Loukides           text/html
# 16                                   Mike Loukides           text/html
# 17                                   Mike Loukides           text/html
# 18                                             NaN           text/html
# 19                                             NaN           text/html
# 20                                   Mike Loukides           text/html
# 21                                   Mike Loukides           text/html
# 22                                   Mike Loukides           text/html
# 23                 Patrick Hall and Ayoub Ouederni           text/html
# 24                                   Mike Loukides           text/html
# 25                                   Mike Loukides           text/html
# 26                                  Nat Torkington           text/html
# 27                                  Nat Torkington           text/html
# 28                                             NaN           text/html
# 29                                   Mike Loukides           text/html
# 30                                  Nat Torkington           text/html
# 31                                  Nat Torkington           text/html
# 32                                   Mike Loukides           text/html
# 33                                  Nat Torkington           text/html
# 34                                  Nat Torkington           text/html
# 35                                  Nat Torkington           text/html
# 36                                   Kevlin Henney           text/html
# 37                                  Nat Torkington           text/html
# 38                                  Nat Torkington           text/html
# 39                                   Mike Loukides           text/html
# 40                                  Nat Torkington           text/html
# 41                                  Nat Torkington           text/html
# 42                                  Nat Torkington           text/html
# 43                                   Mike Loukides           text/html
# 44                                  Nat Torkington           text/html
# 45                                  Nat Torkington           text/html
# 46  Q Ethan McCallum, Chris Butler and Shane Glynn           text/html
# 47                                  Nat Torkington           text/html
# 48                                             NaN           text/html
# 49                                  Nat Torkington           text/html
# 50                 Justin Norman and Mike Loukides           text/html
# 51                                  Nat Torkington           text/html
# 52                                   Mike Loukides           text/html
# 53                                  Nat Torkington           text/html
# 54                                  Nat Torkington           text/html
# 55                                   Mike Loukides           text/html
# 56                                  Nat Torkington           text/html
# 57                                  Nat Torkington           text/html
# 58                                  Nat Torkington           text/html
# 59                                  Nat Torkington           text/html
#
#    summary_detail.language                             summary_detail.base  \
# 0                     None  http://feeds.feedburner.com/oreilly/radar/atom
# 1                     None  http://feeds.feedburner.com/oreilly/radar/atom
# 2                     None  http://feeds.feedburner.com/oreilly/radar/atom
# 3                     None  http://feeds.feedburner.com/oreilly/radar/atom
# 4                     None  http://feeds.feedburner.com/oreilly/radar/atom
# 5                     None  http://feeds.feedburner.com/oreilly/radar/atom
# 6                     None  http://feeds.feedburner.com/oreilly/radar/atom
# 7                     None  http://feeds.feedburner.com/oreilly/radar/atom
# 8                     None  http://feeds.feedburner.com/oreilly/radar/atom
# 9                     None  http://feeds.feedburner.com/oreilly/radar/atom
# 10                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 11                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 12                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 13                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 14                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 15                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 16                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 17                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 18                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 19                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 20                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 21                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 22                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 23                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 24                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 25                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 26                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 27                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 28                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 29                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 30                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 31                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 32                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 33                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 34                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 35                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 36                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 37                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 38                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 39                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 40                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 41                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 42                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 43                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 44                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 45                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 46                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 47                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 48                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 49                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 50                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 51                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 52                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 53                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 54                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 55                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 56                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 57                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 58                    None  http://feeds.feedburner.com/oreilly/radar/atom
# 59                    None  http://feeds.feedburner.com/oreilly/radar/atom
#
#                                  summary_detail.value
# 0   Certainly the biggest news of the past month h...
# 1   We are traveling through the era of Software 2...
# 2   At one point early this year, Elon Musk briefl...
# 3   Home assistants and smart displays are being s...
# 4   A few months ago, I was asked if there were an...
# 5   The most fascinating idea this month is POET, ...
# 6   OpenAI’s text generating system GPT-3 has capt...
# 7   Back in 2019, Ben Lorica and I wrote about  de...
# 8   We’ll start with a moment of silence. RIP Dan ...
# 9   “If you want to be successful in business (in ...
# 10  During the first weeks of February, we asked r...
# 11  It would be hard to miss the commotion around ...
# 12  March was a busy month. There’s been a lot of ...
# 13  It seems harder than ever to agree with others...
# 14  High-profile entrepreneurs like Elon Musk, ven...
# 15  Programs like AlphaZero and GPT-3 are massive ...
# 16  For a short month, a lot happened in February–...
# 17  A couple of years ago, Pete Skomoroch, Roger M...
# 18  Here are some of the most significant themes w...
# 19  Change is the only constant in the technology ...
# 20  “If they can get you asking the wrong question...
# 21  A lot happened in the last month, and not just...
# 22  In this report, we look at the data generated ...
# 23  “[T]he threats to consumers arising from data ...
# 24  A few months ago, I said that &#8220;making ev...
# 25  The last month of the old year showed a lot of...
# 26  End-to-end Entity Resolution for Big Data — In...
# 27  TextAttack — Framework for generating adversar...
# 28  2020 has been a year of great challenges for s...
# 29  It has long seemed to me that functional progr...
# 30  NAND Game &#8212; You start with a single comp...
# 31  AlphaFold &#8212; This is astonishing: protein...
# 32  This month’s collection of interesting article...
# 33  Brian Kernighan Interviews Ken Thompson &#8212...
# 34  OpenStreetMap is Having a Moment &#8212; Apple...
# 35  epr &#8212; Terminal/CLI Epub reader. I Should...
# 36  If software is such stuff as dreams are made o...
# 37  NDSS Symposium 2020 Papers &#8212; Large pile ...
# 38  Advanced System on a Chip Lecture Notes (2016)...
# 39  The programming world used to be split into fu...
# 40  Hypothesis as Liability &#8212; Would the ment...
# 41  Dealing with Security Holes in Chips &#8212; s...
# 42  The AI Who Mistook a Bald Head for a Football ...
# 43  Perhaps the most important event this month is...
# 44  Mutation Testing &#8212; in this paper, we sem...
# 45  Phantom of the ADAS &#8212; In this paper, we ...
# 46  &#8220;On peut interroger n&#8217;importe qui,...
# 47  Justice Department Antitrust Filing Against Go...
# 48  Automerge &#8212; (Github) Data structure libr...
# 49  Data Organization in Spreadsheets &#8212; Focu...
# 50  The field of AI product management continues t...
# 51  T-SQL in SQLite &#8212; CG/SQL is a code gener...
# 52  The release of GPT-3 has reinvigorated a discu...
# 53  Algorithms Can Collude &#8212; To analyze the ...
# 54  Single Device Behaves Like a Neuron &#8212; On...
# 55  This month, the big surprise is that there’s n...
# 56  When Coffeemakers Demand Ransom &#8212; So he ...
# 57  Adapton &#8212; A program P is incremental if ...
# 58  CS349 &#8211; Contemporary Issues in Computer ...
# 59  A Concurrency Cost Hierarchy &#8212; a higher ...
#
# [60 rows x 25 columns]

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
df.groupby('author')['title'].count().sort_values(ascending=False)
# Out:
# author
# Nat Torkington                                    23
# Mike Loukides                                     22
#                                                    4
# Tim O’Reilly                                       3
# Chris Butler                                       1
# Hugo Bowne-Anderson                                1
# Justin Norman and Mike Loukides                    1
# Kevlin Henney                                      1
# Nitesh Dhanjani                                    1
# Patrick Hall and Ayoub Ouederni                    1
# Q Ethan McCallum, Chris Butler and Shane Glynn     1
# Shayan Mohanty and Hugo Bowne-Anderson             1
# Name: title, dtype: int64

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
df['length_title'] = df['title'].apply(lambda x: len(x))
dg = df[['title','author','length_title']].sort_values(by='length_title',ascending=False)
dg.reset_index(drop=True).head(10)
# Out:
#                                                title  \
# 0  Where Programming, Ops, AI, and the Cloud are ...
# 1  AI Powered Misinformation and Manipulation at ...
# 2  5 infrastructure and operations trends to watc...
# 3  O’Reilly’s top 20 live online training courses...
# 4         5 things on our data and AI radar for 2021
# 5          Seven Legal Questions for Data Scientists
# 6           The End of Silicon Valley as We Know It?
# 7             AI Product Management After Deployment
# 8               Radar trends to watch: November 2020
# 9               Radar trends to watch: December 2020
#
#                             author  length_title
# 0                    Mike Loukides            60
# 1                  Nitesh Dhanjani            58
# 2                                             55
# 3                                             54
# 4                                             42
# 5  Patrick Hall and Ayoub Ouederni            41
# 6                     Tim O’Reilly            40
# 7  Justin Norman and Mike Loukides            38
# 8                    Mike Loukides            36
# 9                    Mike Loukides            36

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
list_ml = []
for s in d.entries:
    if 'machine learning' in s.summary:
        list_ml.append(s.title)
list_ml
# Out:
# ['Hand Labeling Considered Harmful',
#  'Radar trends to watch: April 2021',
#  'Seven Legal Questions for Data Scientists']
